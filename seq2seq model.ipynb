# %%
import tensorflow as tf
from tensorflow.python.layers.core import Dense
import numpy as np

# %%
with open("letters_source.txt", 'r', encoding="utf-8") as f:
    source_data = f.read()
with open("letters_target.txt", 'r', encoding="utf-8") as p:
    target_data = p.read()

# %%
def extract_character_vocab(data):
    #构造映射表
    special_words = ['<PAD>', 'UNK', '<GO>', '<EOS>']
    set_words = list(set([character for line in data.split('\n') for character in line]))
    #把4个特殊字符放进词典
    int_to_vocab = {idx: word for idx, word in enumerate(special_words + set_words)}
    vocab_to_int = {word: idx for idx, word in int_to_vocab.items()}
    
    return int_to_vocab, vocab_to_int

# %%
source_int_to_letter, source_letter_to_int = extract_character_vocab(source_data)
target_int_to_letter, target_letter_to_int = extract_character_vocab(target_data)

# %%
source_int = [[source_letter_to_int.get(letter, source_letter_to_int['UNK']) for letter in line] for line in source_data.split('\n')]
target_int = [[target_letter_to_int.get(letter, target_letter_to_int['UNK']) for letter in line] for line in target_data.split('\n')]

# %%
special_words = ['<PAD>', 'UNK', '<GO>', '<EOS>']
set_words = list(set([character for line in target_data.split('\n') for character in line]))
print(set_words)
# Out:
# ['e', 'i', 'x', 'r', 'm', 'g', 'j', 't', 's', 'd', 'b', 'l', 'h', 'n', 'v', 'y', 'q', 'w', 'c', 'o', 'a', 'z', 'u', 'f', 'p', 'k']

# %%
def get_inputs():
    inputs = tf.placeholder(tf.int32, [None, None], name="inputs")
    targets = tf.placeholder(tf.int32, [None, None], name="targets")
    learning_rate = tf.placeholder(tf.float32, name="learning_rate")
    
    target_sequence_length = tf.placeholder(tf.int32, (None,), name="target_sequence_length")
    max_target_sequence_length = tf.reduce_max(target_sequence_length, name="max_target_len")
    source_sequence_length = tf.placeholder(tf.int32, (None,), name="source_sequence_length")
    

    return inputs, targets, learning_rate, target_sequence_length, max_target_sequence_length, source_sequence_length

# %%
def get_encoder_layer(input_data, rnn_size, num_layers, source_sequence_length, source_vocab_size, encoding_embedding_size):
    #encode embedding
    encoder_embed_input = tf.contrib.layers.embed_sequence(input_data, source_vocab_size, encoding_embedding_size)
    #RNN cell
    def get_lstm_cell(rnn_size):
        lstm_cell = tf.contrib.rnn.LSTMCell(rnn_size, initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
        return lstm_cell 
    cell = tf.contrib.rnn.MultiRNNCell([get_lstm_cell(rnn_size) for _ in range(num_layers)])
    
    encoder_output, encoder_state = tf.nn.dynamic_rnn(cell, encoder_embed_input, sequence_length=source_sequence_length, dtype=tf.float32)
    
    return encoder_output, encoder_state

# %%
def process_decoder_input(data, vocab_to_int, batch_size):
    ending = tf.strided_slice(data, [0, 0], [batch_size, -1], [1, 1])
    decoder_input = tf.concat([tf.fill([batch_size, 1], vocab_to_int['<GO>']), ending], 1)
    return decoder_input

# %%
def decoding_layer(target_letter_to_int, decoding_embedding_size, num_layers, rnn_size, target_sequence_length, max_target_sequence_length,
                  encoder_state, decoder_input):
    #1 Embedding
    target_vocab_size = len(target_letter_to_int)
    decoder_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, decoding_embedding_size]))
    decoder_embed_input = tf.nn.embedding_lookup(decoder_embeddings, decoder_input)
    
    #2 构造Decoder中的RNN单元
    def get_decoder_cell(rnn_size):
        decoder_cell = tf.contrib.rnn.LSTMCell(rnn_size, initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
        
        return decoder_cell
    cell = tf.contrib.rnn.MultiRNNCell([get_decoder_cell(rnn_size) for _ in range(num_layers)])
    
    #3 Output全连接层
    output_layer = Dense(target_vocab_size, kernel_initializer=tf.truncated_normal_initializer(mean=0.0, stddev=0.1))
    
    #4 Training decoder
    with tf.variable_scope("decode"):
        training_helper = tf.contrib.seq2seq.TrainingHelper(inputs=decoder_embed_input, sequence_length=target_sequence_length, time_major=False)
        
        training_decoder = tf.contrib.seq2seq.BasicDecoder(cell, training_helper, encoder_state, output_layer)
        
        training_decoder_output, _, _ = tf.contrib.seq2seq.dynamic_decode(training_decoder, impute_finished=True, maximum_iterations=max_target_sequence_length)
    
    #5 Predict decoder
    with tf.variable_scope("decode", reuse=True):
        start_tokens = tf.tile(tf.constant([target_letter_to_int['<GO>']], dtype=tf.int32), [batch_size], name="start_tokens")
        
        predicting_helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(decoder_embeddings, start_tokens, target_letter_to_int['<EOS>'])
        predicting_decoder = tf.contrib.seq2seq.BasicDecoder(cell, predicting_helper, encoder_state, output_layer)
        
        predicting_decoder_output, _, _ = tf.contrib.seq2seq.dynamic_decode(predicting_decoder, impute_finished=True, maximum_iterations=max_target_sequence_length)
        
    return training_decoder_output, predicting_decoder_output

# %%
def seq2seq_model(input_data, targets, lr, target_sequence_length, max_target_sequence_length, source_sequence_length, source_vocab_size,
                 target_vocab_size, encoder_embedding_size, decoder_embedding_size, rnn_size, num_layers):
    # 获取encoder的状态输出
    _, encoder_state = get_encoder_layer(input_data, rnn_size, num_layers, source_sequence_length, source_vocab_size, encoding_embedding_size)
    
    #预处理后的decoder输入
    decoder_input = process_decoder_input(targets, target_letter_to_int, batch_size)
    
    #将状态向量与输入传递给decoder
    training_decoder_output, predicting_decoder_output = decoding_layer(target_letter_to_int, 
                                                                        decoding_embedding_size, 
                                                                        num_layers, rnn_size,
                                                                       target_sequence_length, 
                                                                        max_target_sequence_length, 
                                                                        encoder_state, 
                                                                        decoder_input)
    return training_decoder_output, predicting_decoder_output

# %%
#超参数
epochs = 50
batch_size = 128
rnn_size = 50
num_layers = 2
encoding_embedding_size = 15
decoding_embedding_size = 15
learning_rate = 0.001

# %%
train_graph = tf.Graph()

with train_graph.as_default():
    input_data, targets, lr, target_sequence_length, max_target_sequence_length, source_sequence_length = get_inputs()
    training_decoder_output, predicting_decoder_output = seq2seq_model(input_data, targets, lr, target_sequence_length, max_target_sequence_length,
                                                                      source_sequence_length, len(source_letter_to_int), len(target_letter_to_int),
                                                                      encoding_embedding_size, decoding_embedding_size, rnn_size, num_layers)
    training_logits = tf.identity(training_decoder_output.rnn_output, 'logits')
    predicting_logits = tf.identity(predicting_decoder_output.sample_id, name="prediction")
    
    masks = tf.sequence_mask(target_sequence_length, max_target_sequence_length, dtype=tf.float32, name="mask")
    
    with tf.name_scope("optimization"):
        
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping 基于定义的min与max对tesor数据进行截断操作，目的是为了应对梯度爆发或者梯度消失的情况
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -5., 5.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %%
def pad_sentence_batch(sentence_batch, pad_int):
    '''
    对batch中的序列进行补全，保证batch中的每行都有相同的sequence_length
    
    参数：
    - sentence batch
    - pad_int: <PAD>对应索引号
    '''
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [pad_int] * (max_sentence - len(sentence)) for sentence in sentence_batch]

# %%
def get_batches(targets, sources, batch_size, source_pad_int, target_pad_int):
    '''
    定义生成器，用来获取batch
    '''
    for batch_i in range(0, len(sources)//batch_size):
        start_i = batch_i * batch_size
        sources_batch = sources[start_i:start_i + batch_size]
        targets_batch = targets[start_i:start_i + batch_size]
        # 补全序列
        pad_sources_batch = np.array(pad_sentence_batch(sources_batch, source_pad_int))
        pad_targets_batch = np.array(pad_sentence_batch(targets_batch, target_pad_int))
        
        # 记录每条记录的长度
        pad_targets_lengths = []
        for target in pad_targets_batch:
            pad_targets_lengths.append(len(target))
        
        pad_source_lengths = []
        for source in pad_sources_batch:
            pad_source_lengths.append(len(source))
        
        yield pad_targets_batch, pad_sources_batch, pad_targets_lengths, pad_source_lengths

# %%
# 将数据集分割为train和validation
train_source = source_int[batch_size:]
train_target = target_int[batch_size:]
# 留出一个batch进行验证
valid_source = source_int[:batch_size]
valid_target = target_int[:batch_size]
(valid_targets_batch, valid_sources_batch, valid_targets_lengths, valid_sources_lengths) = next(get_batches(valid_target, valid_source, batch_size,
                           source_letter_to_int['<PAD>'],
                           target_letter_to_int['<PAD>']))

display_step = 50 # 每隔50轮输出loss

checkpoint = "./trained_model.ckpt" 
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())
        
    for epoch_i in range(1, epochs+1):
        for batch_i, (targets_batch, sources_batch, targets_lengths, sources_lengths) in enumerate(
                get_batches(train_target, train_source, batch_size,
                           source_letter_to_int['<PAD>'],
                           target_letter_to_int['<PAD>'])):
            
            _, loss = sess.run(
                [train_op, cost],
                {input_data: sources_batch,
                 targets: targets_batch,
                 lr: learning_rate,
                 target_sequence_length: targets_lengths,
                 source_sequence_length: sources_lengths})

            if batch_i % display_step == 0:
                
                # 计算validation loss
                validation_loss = sess.run(
                [cost],
                {input_data: valid_sources_batch,
                 targets: valid_targets_batch,
                 lr: learning_rate,
                 target_sequence_length: valid_targets_lengths,
                 source_sequence_length: valid_sources_lengths})
                
                print('Epoch {:>3}/{} Batch {:>4}/{} - Training Loss: {:>6.3f}  - Validation loss: {:>6.3f}'
                      .format(epoch_i,
                              epochs, 
                              batch_i, 
                              len(train_source) // batch_size, 
                              loss, 
                              validation_loss[0]))

    
    
    # 保存模型
    saver = tf.train.Saver()
    saver.save(sess, checkpoint)
    print('Model Trained and Saved')
# Out:
# Epoch   1/50 Batch    0/77 - Training Loss:  3.397  - Validation loss:  3.385
# Epoch   1/50 Batch   50/77 - Training Loss:  2.420  - Validation loss:  2.153
# Epoch   2/50 Batch    0/77 - Training Loss:  2.098  - Validation loss:  1.956
# Epoch   2/50 Batch   50/77 - Training Loss:  2.022  - Validation loss:  1.779
# Epoch   3/50 Batch    0/77 - Training Loss:  1.775  - Validation loss:  1.652
# Epoch   3/50 Batch   50/77 - Training Loss:  1.735  - Validation loss:  1.547
# Epoch   4/50 Batch    0/77 - Training Loss:  1.576  - Validation loss:  1.485
# Epoch   4/50 Batch   50/77 - Training Loss:  1.525  - Validation loss:  1.352
# Epoch   5/50 Batch    0/77 - Training Loss:  1.400  - Validation loss:  1.306
# Epoch   5/50 Batch   50/77 - Training Loss:  1.395  - Validation loss:  1.218
# Epoch   6/50 Batch    0/77 - Training Loss:  1.263  - Validation loss:  1.167
# Epoch   6/50 Batch   50/77 - Training Loss:  1.240  - Validation loss:  1.077
# Epoch   7/50 Batch    0/77 - Training Loss:  1.117  - Validation loss:  1.026
# Epoch   7/50 Batch   50/77 - Training Loss:  1.096  - Validation loss:  0.927
# Epoch   8/50 Batch    0/77 - Training Loss:  0.973  - Validation loss:  0.887
# Epoch   8/50 Batch   50/77 - Training Loss:  0.966  - Validation loss:  0.804
# Epoch   9/50 Batch    0/77 - Training Loss:  0.858  - Validation loss:  0.784
# Epoch   9/50 Batch   50/77 - Training Loss:  0.873  - Validation loss:  0.718
# Epoch  10/50 Batch    0/77 - Training Loss:  0.771  - Validation loss:  0.710
# Epoch  10/50 Batch   50/77 - Training Loss:  0.766  - Validation loss:  0.625
# Epoch  11/50 Batch    0/77 - Training Loss:  0.674  - Validation loss:  0.597
# Epoch  11/50 Batch   50/77 - Training Loss:  0.669  - Validation loss:  0.536
# Epoch  12/50 Batch    0/77 - Training Loss:  0.604  - Validation loss:  0.515
# Epoch  12/50 Batch   50/77 - Training Loss:  0.604  - Validation loss:  0.477
# Epoch  13/50 Batch    0/77 - Training Loss:  0.532  - Validation loss:  0.462
# Epoch  13/50 Batch   50/77 - Training Loss:  0.543  - Validation loss:  0.426
# Epoch  14/50 Batch    0/77 - Training Loss:  0.478  - Validation loss:  0.411
# Epoch  14/50 Batch   50/77 - Training Loss:  0.485  - Validation loss:  0.375
# Epoch  15/50 Batch    0/77 - Training Loss:  0.424  - Validation loss:  0.362
# Epoch  15/50 Batch   50/77 - Training Loss:  0.431  - Validation loss:  0.328
# Epoch  16/50 Batch    0/77 - Training Loss:  0.373  - Validation loss:  0.315
# Epoch  16/50 Batch   50/77 - Training Loss:  0.380  - Validation loss:  0.285
# Epoch  17/50 Batch    0/77 - Training Loss:  0.324  - Validation loss:  0.276
# Epoch  17/50 Batch   50/77 - Training Loss:  0.331  - Validation loss:  0.246
# Epoch  18/50 Batch    0/77 - Training Loss:  0.284  - Validation loss:  0.268
# Epoch  18/50 Batch   50/77 - Training Loss:  0.290  - Validation loss:  0.217
# Epoch  19/50 Batch    0/77 - Training Loss:  0.244  - Validation loss:  0.202
# Epoch  19/50 Batch   50/77 - Training Loss:  0.256  - Validation loss:  0.188
# Epoch  20/50 Batch    0/77 - Training Loss:  0.213  - Validation loss:  0.177
# Epoch  20/50 Batch   50/77 - Training Loss:  0.228  - Validation loss:  0.164
# Epoch  21/50 Batch    0/77 - Training Loss:  0.184  - Validation loss:  0.157
# Epoch  21/50 Batch   50/77 - Training Loss:  0.202  - Validation loss:  0.146
# Epoch  22/50 Batch    0/77 - Training Loss:  0.160  - Validation loss:  0.140
# Epoch  22/50 Batch   50/77 - Training Loss:  0.176  - Validation loss:  0.133
# Epoch  23/50 Batch    0/77 - Training Loss:  0.145  - Validation loss:  0.123
# Epoch  23/50 Batch   50/77 - Training Loss:  0.158  - Validation loss:  0.119
# Epoch  24/50 Batch    0/77 - Training Loss:  0.131  - Validation loss:  0.116
# Epoch  24/50 Batch   50/77 - Training Loss:  0.143  - Validation loss:  0.108
# Epoch  25/50 Batch    0/77 - Training Loss:  0.113  - Validation loss:  0.104
# Epoch  25/50 Batch   50/77 - Training Loss:  0.141  - Validation loss:  0.102
# Epoch  26/50 Batch    0/77 - Training Loss:  0.104  - Validation loss:  0.098
# Epoch  26/50 Batch   50/77 - Training Loss:  0.115  - Validation loss:  0.089
# Epoch  27/50 Batch    0/77 - Training Loss:  0.092  - Validation loss:  0.085
# Epoch  27/50 Batch   50/77 - Training Loss:  0.103  - Validation loss:  0.082
# Epoch  28/50 Batch    0/77 - Training Loss:  0.083  - Validation loss:  0.077
# Epoch  28/50 Batch   50/77 - Training Loss:  0.094  - Validation loss:  0.075
# Epoch  29/50 Batch    0/77 - Training Loss:  0.075  - Validation loss:  0.071
# Epoch  29/50 Batch   50/77 - Training Loss:  0.087  - Validation loss:  0.070
# Epoch  30/50 Batch    0/77 - Training Loss:  0.069  - Validation loss:  0.065
# Epoch  30/50 Batch   50/77 - Training Loss:  0.081  - Validation loss:  0.068
# Epoch  31/50 Batch    0/77 - Training Loss:  0.064  - Validation loss:  0.060
# Epoch  31/50 Batch   50/77 - Training Loss:  0.073  - Validation loss:  0.063
# Epoch  32/50 Batch    0/77 - Training Loss:  0.059  - Validation loss:  0.054
# Epoch  32/50 Batch   50/77 - Training Loss:  0.067  - Validation loss:  0.055
# Epoch  33/50 Batch    0/77 - Training Loss:  0.053  - Validation loss:  0.051
# Epoch  33/50 Batch   50/77 - Training Loss:  0.060  - Validation loss:  0.050
# Epoch  34/50 Batch    0/77 - Training Loss:  0.049  - Validation loss:  0.049
# Epoch  34/50 Batch   50/77 - Training Loss:  0.055  - Validation loss:  0.047
# Epoch  35/50 Batch    0/77 - Training Loss:  0.044  - Validation loss:  0.047
# Epoch  35/50 Batch   50/77 - Training Loss:  0.051  - Validation loss:  0.044
# Epoch  36/50 Batch    0/77 - Training Loss:  0.041  - Validation loss:  0.044
# Epoch  36/50 Batch   50/77 - Training Loss:  0.047  - Validation loss:  0.041
# Epoch  37/50 Batch    0/77 - Training Loss:  0.037  - Validation loss:  0.041
# Epoch  37/50 Batch   50/77 - Training Loss:  0.044  - Validation loss:  0.038
# Epoch  38/50 Batch    0/77 - Training Loss:  0.034  - Validation loss:  0.039
# Epoch  38/50 Batch   50/77 - Training Loss:  0.041  - Validation loss:  0.035
# Epoch  39/50 Batch    0/77 - Training Loss:  0.032  - Validation loss:  0.036
# Epoch  39/50 Batch   50/77 - Training Loss:  0.038  - Validation loss:  0.033
# Epoch  40/50 Batch    0/77 - Training Loss:  0.030  - Validation loss:  0.034
# Epoch  40/50 Batch   50/77 - Training Loss:  0.035  - Validation loss:  0.031
# Epoch  41/50 Batch    0/77 - Training Loss:  0.028  - Validation loss:  0.033
# Epoch  41/50 Batch   50/77 - Training Loss:  0.032  - Validation loss:  0.028
# Epoch  42/50 Batch    0/77 - Training Loss:  0.026  - Validation loss:  0.032
# Epoch  42/50 Batch   50/77 - Training Loss:  0.031  - Validation loss:  0.027
# Epoch  43/50 Batch    0/77 - Training Loss:  0.025  - Validation loss:  0.031
# Epoch  43/50 Batch   50/77 - Training Loss:  0.031  - Validation loss:  0.031
# Epoch  44/50 Batch    0/77 - Training Loss:  0.024  - Validation loss:  0.030
# Epoch  44/50 Batch   50/77 - Training Loss:  0.028  - Validation loss:  0.027
# Epoch  45/50 Batch    0/77 - Training Loss:  0.023  - Validation loss:  0.028
# Epoch  45/50 Batch   50/77 - Training Loss:  0.026  - Validation loss:  0.022
# Epoch  46/50 Batch    0/77 - Training Loss:  0.020  - Validation loss:  0.030
# Epoch  46/50 Batch   50/77 - Training Loss:  0.024  - Validation loss:  0.022
# Epoch  47/50 Batch    0/77 - Training Loss:  0.019  - Validation loss:  0.027
# Epoch  47/50 Batch   50/77 - Training Loss:  0.022  - Validation loss:  0.019
# Epoch  48/50 Batch    0/77 - Training Loss:  0.017  - Validation loss:  0.026
# Epoch  48/50 Batch   50/77 - Training Loss:  0.020  - Validation loss:  0.020
# Epoch  49/50 Batch    0/77 - Training Loss:  0.015  - Validation loss:  0.024
# Epoch  49/50 Batch   50/77 - Training Loss:  0.018  - Validation loss:  0.019
# Epoch  50/50 Batch    0/77 - Training Loss:  0.014  - Validation loss:  0.023
# Epoch  50/50 Batch   50/77 - Training Loss:  0.018  - Validation loss:  0.018
# Model Trained and Saved

# %%
def source_to_seq(text):
    '''
    对源数据进行转换
    '''
    sequence_length = 7
    return [source_letter_to_int.get(word, source_letter_to_int['UNK']) for word in text] + [source_letter_to_int['<PAD>']]*(sequence_length-len(text))

# %%
# 输入一个单词
input_word = 'zgy'
text = source_to_seq(input_word)

checkpoint = "./trained_model.ckpt"

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # 加载模型
    loader = tf.train.import_meta_graph(checkpoint + '.meta')
    loader.restore(sess, checkpoint)

    input_data = loaded_graph.get_tensor_by_name('inputs:0')
    logits = loaded_graph.get_tensor_by_name('prediction:0')
    source_sequence_length = loaded_graph.get_tensor_by_name('source_sequence_length:0')
    target_sequence_length = loaded_graph.get_tensor_by_name('target_sequence_length:0')
    
    answer_logits = sess.run(logits, {input_data: [text]*batch_size, 
                                      target_sequence_length: [len(text)]*batch_size, 
                                      source_sequence_length: [len(text)]*batch_size})[0] 


pad = source_letter_to_int["<PAD>"] 

print('原始输入:', input_word)

print('\nSource')
print('  Word 编号:    {}'.format([i for i in text]))
print('  Input Words: {}'.format(" ".join([source_int_to_letter[i] for i in text])))

print('\nTarget')
print('  Word 编号:       {}'.format([i for i in answer_logits if i != pad]))
print('  Response Words: {}'.format(" ".join([target_int_to_letter[i] for i in answer_logits if i != pad])))
# Out:
# INFO:tensorflow:Restoring parameters from ./trained_model.ckpt
# 原始输入: zgy
#
# Source
#   Word 编号:    [25, 9, 19, 0, 0, 0, 0]
#   Input Words: z g y <PAD> <PAD> <PAD> <PAD>
#
# Target
#   Word 编号:       [9, 19, 25]
#   Response Words: g y z

# %%
import tensorflow as tf
a = tf.Variable(tf.random_uniform([2, 3]))
b = tf.nn.embedding_lookup(a, [1])
sess = tf.Session()
sess.run(tf.global_variables_initializer())
print(sess.run(a))
print(sess.run(b))
# Out:
# [[0.6062417  0.69579077 0.4380113 ]
#  [0.5330955  0.21517694 0.07314157]]
# [[0.5330955  0.21517694 0.07314157]]
